# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization # type: ignore
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
from sklearn.impute import SimpleImputer

# %%
# Data Loading
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# Label Separation
X = train.drop(columns = ['ID', 'SUBCLASS'], axis=1)
y = train['SUBCLASS']

# %%
# 결측치 처리
imputer = SimpleImputer(strategy='most_frequent')
test = test.drop(columns = 'ID')
test = pd.DataFrame(imputer.fit_transform(test), columns=test.columns)

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# train.csv 
oe = OrdinalEncoder()
X_df = oe.fit_transform(X)
data = pd.DataFrame(X_df).copy()
data.columns = X.columns

# test.csv
temporary_columns = test.columns
test = pd.DataFrame(oe.fit_transform(test))
test.columns = temporary_columns


# y Data
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# Macro F1 Score를 계산하는 사용자 정의 메트릭
class MacroF1Score(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name='macro_f1_score', **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.true_positives = self.add_weight(name='tp', initializer='zeros', shape=(num_classes,))
        self.false_positives = self.add_weight(name='fp', initializer='zeros', shape=(num_classes,))
        self.false_negatives = self.add_weight(name='fn', initializer='zeros', shape=(num_classes,))

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(tf.argmax(y_pred, axis=1), [-1])
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=self.num_classes)
        y_pred = tf.one_hot(tf.cast(y_pred, tf.int32), depth=self.num_classes)
        
        self.true_positives.assign_add(tf.reduce_sum(y_true * y_pred, axis=0))
        self.false_positives.assign_add(tf.reduce_sum((1 - y_true) * y_pred, axis=0))
        self.false_negatives.assign_add(tf.reduce_sum(y_true * (1 - y_pred), axis=0))

    def result(self):
        precision = self.true_positives / (self.true_positives + self.false_positives + tf.keras.backend.epsilon())
        recall = self.true_positives / (self.true_positives + self.false_negatives + tf.keras.backend.epsilon())
        f1 = 2 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
        return tf.reduce_mean(f1)

    def reset_state(self):
        self.true_positives.assign(tf.zeros_like(self.true_positives))
        self.false_positives.assign(tf.zeros_like(self.false_positives))
        self.false_negatives.assign(tf.zeros_like(self.false_negatives))

# %%
# 모델 정의
from tensorflow import keras # type: ignore
from tensorflow.keras import layers # type: ignore
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=(data.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(26, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=[MacroF1Score(num_classes=26)])
# Out:
# C:\Users\seren\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 모델 학습
history = model.fit(
    data, y,
    epochs=100,
    batch_size=32
)
# Out:
# Epoch 1/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.6103 - macro_f1_score: 0.0685
# Epoch 2/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7395 - macro_f1_score: 0.1456
# Epoch 3/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.4027 - macro_f1_score: 0.1892
# Epoch 4/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.2258 - macro_f1_score: 0.2296
# Epoch 5/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.0715 - macro_f1_score: 0.2715
# Epoch 6/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8800 - macro_f1_score: 0.3132
# Epoch 7/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.7535 - macro_f1_score: 0.3662
# Epoch 8/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6426 - macro_f1_score: 0.4015
# Epoch 9/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5371 - macro_f1_score: 0.4402
# Epoch 10/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4852 - macro_f1_score: 0.4566
# Epoch 11/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3733 - macro_f1_score: 0.4841
# Epoch 12/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3555 - macro_f1_score: 0.5299
# Epoch 13/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2420 - macro_f1_score: 0.5404
# Epoch 14/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1495 - macro_f1_score: 0.5786
# Epoch 15/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1358 - macro_f1_score: 0.5929
# Epoch 16/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0686 - macro_f1_score: 0.5960
# Epoch 17/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 1.0299 - macro_f1_score: 0.6158
# Epoch 18/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0404 - macro_f1_score: 0.6177
# Epoch 19/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.9361 - macro_f1_score: 0.6518
# Epoch 20/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.9469 - macro_f1_score: 0.6601
# Epoch 21/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.9186 - macro_f1_score: 0.6711
# Epoch 22/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8950 - macro_f1_score: 0.6726
# Epoch 23/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.8680 - macro_f1_score: 0.6762
# Epoch 24/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8423 - macro_f1_score: 0.6871
# Epoch 25/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8703 - macro_f1_score: 0.6758
# Epoch 26/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8417 - macro_f1_score: 0.6802
# Epoch 27/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.8026 - macro_f1_score: 0.7097
# Epoch 28/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7585 - macro_f1_score: 0.7162
# Epoch 29/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7810 - macro_f1_score: 0.7123
# Epoch 30/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7449 - macro_f1_score: 0.7224
# Epoch 31/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7135 - macro_f1_score: 0.7194
# Epoch 32/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7282 - macro_f1_score: 0.7228
# Epoch 33/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6879 - macro_f1_score: 0.7338
# Epoch 34/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7128 - macro_f1_score: 0.7486
# Epoch 35/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7052 - macro_f1_score: 0.7456
# Epoch 36/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6545 - macro_f1_score: 0.7534
# Epoch 37/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6477 - macro_f1_score: 0.7564
# Epoch 38/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6391 - macro_f1_score: 0.7658
# Epoch 39/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6378 - macro_f1_score: 0.7697
# Epoch 40/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6205 - macro_f1_score: 0.7720
# Epoch 41/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6263 - macro_f1_score: 0.7726
# Epoch 42/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6178 - macro_f1_score: 0.7774
# Epoch 43/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6492 - macro_f1_score: 0.7587
# Epoch 44/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6094 - macro_f1_score: 0.7665
# Epoch 45/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6125 - macro_f1_score: 0.7710
# Epoch 46/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.5822 - macro_f1_score: 0.7826
# Epoch 47/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5781 - macro_f1_score: 0.7865
# Epoch 48/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6132 - macro_f1_score: 0.7600
# Epoch 49/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5901 - macro_f1_score: 0.7798
# Epoch 50/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5941 - macro_f1_score: 0.7728
# Epoch 51/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6232 - macro_f1_score: 0.7554
# Epoch 52/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5970 - macro_f1_score: 0.7750
# Epoch 53/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5628 - macro_f1_score: 0.7896
# Epoch 54/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5847 - macro_f1_score: 0.7821
# Epoch 55/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5790 - macro_f1_score: 0.7901
# Epoch 56/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.5530 - macro_f1_score: 0.7920
# Epoch 57/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.5603 - macro_f1_score: 0.7854
# Epoch 58/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5907 - macro_f1_score: 0.7821
# Epoch 59/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5452 - macro_f1_score: 0.8014
# Epoch 60/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5628 - macro_f1_score: 0.7853
# Epoch 61/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.5180 - macro_f1_score: 0.8102
# Epoch 62/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5807 - macro_f1_score: 0.7845
# Epoch 63/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5354 - macro_f1_score: 0.7963
# Epoch 64/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5010 - macro_f1_score: 0.8102
# Epoch 65/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4968 - macro_f1_score: 0.8139
# Epoch 66/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5299 - macro_f1_score: 0.8042
# Epoch 67/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5127 - macro_f1_score: 0.8023
# Epoch 68/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4952 - macro_f1_score: 0.8099
# Epoch 69/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5083 - macro_f1_score: 0.8095
# Epoch 70/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5234 - macro_f1_score: 0.8027
# Epoch 71/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5172 - macro_f1_score: 0.8123
# Epoch 72/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5260 - macro_f1_score: 0.8075
# Epoch 73/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.5221 - macro_f1_score: 0.8011
# Epoch 74/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5216 - macro_f1_score: 0.8118
# Epoch 75/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5073 - macro_f1_score: 0.8238
# Epoch 76/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5040 - macro_f1_score: 0.8085
# Epoch 77/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5037 - macro_f1_score: 0.8136
# Epoch 78/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4776 - macro_f1_score: 0.8228
# Epoch 79/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4894 - macro_f1_score: 0.8186
# Epoch 80/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5082 - macro_f1_score: 0.8071
# Epoch 81/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4973 - macro_f1_score: 0.8213
# Epoch 82/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4782 - macro_f1_score: 0.8179
# Epoch 83/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4733 - macro_f1_score: 0.8279
# Epoch 84/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.5008 - macro_f1_score: 0.8240
# Epoch 85/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4776 - macro_f1_score: 0.8205
# Epoch 86/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4586 - macro_f1_score: 0.8338
# Epoch 87/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4817 - macro_f1_score: 0.8189
# Epoch 88/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4691 - macro_f1_score: 0.8265
# Epoch 89/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4646 - macro_f1_score: 0.8293
# Epoch 90/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.5099 - macro_f1_score: 0.8207
# Epoch 91/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4685 - macro_f1_score: 0.8229
# Epoch 92/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4765 - macro_f1_score: 0.8235
# Epoch 93/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4918 - macro_f1_score: 0.8173
# Epoch 94/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4979 - macro_f1_score: 0.8221
# Epoch 95/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4719 - macro_f1_score: 0.8288
# Epoch 96/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4592 - macro_f1_score: 0.8292
# Epoch 97/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4663 - macro_f1_score: 0.8260
# Epoch 98/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4656 - macro_f1_score: 0.8283
# Epoch 99/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4783 - macro_f1_score: 0.8262
# Epoch 100/100
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4772 - macro_f1_score: 0.8326

# %%
# 테스트 데이터 예측
predictions = model.predict(test)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 예측 결과를 원래 레이블로 변환
predicted_labels = le.inverse_transform(predicted_classes)

# %%
result = pd.DataFrame(predicted_labels)

final = sample.copy()
final['SUBCLASS'] = result

# %%
final.to_csv("./final.csv", index=False)
